# %% [markdown]
# # Process mining
#
# Questo notebook serve per le analisi di process mining sul dataset 'event_log.csv'

# %%
import pandas as pd

df = pd.read_csv('dataset/event_log.csv')
df.head(30)
# Out:
#      case_id           activity chamber               time  \
# 0   25G00016      presentazione  camera    19 ottobre 2022
# 1   25G00016       assegnazione  camera   23 novembre 2022
# 2   25G00016  esame_commissione  camera   28 novembre 2023
# 3   25G00016         esame_aula  camera    16 ottobre 2024
# 4   25G00016       assegnazione  camera    17 ottobre 2024
# 5   25G00016       approvazione  camera    17 ottobre 2024
# 6   25G00016       assegnazione  senato    30 ottobre 2024
# 7   25G00016  esame_commissione  senato   18 dicembre 2024
# 8   25G00016       approvazione  senato    22 gennaio 2025
# 9   25G00014       assegnazione  camera    22 gennaio 2025
# 10  25G00014  esame_commissione  camera    23 gennaio 2025
# 11  25G00014         esame_aula  camera    28 gennaio 2025
# 12  25G00014       approvazione  camera    28 gennaio 2025
# 13  25G00014      presentazione  senato   27 dicembre 2024
# 14  25G00014       assegnazione  senato   28 dicembre 2024
# ...
